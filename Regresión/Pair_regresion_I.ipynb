# %% [markdown]
# # <span style="color:orange">25/05 - Pair Regresión 1- Alicia y Lidia</span>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sidetable

import statsmodels.api as sm
import pylab as py
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %% [markdown]
# Buscar un conjunto de datos a analizar:
# - Se recomienda que el conjunto de datos a analizar tenga variables numéricas y categóricas y limpio.

# %%
df = pd.read_csv('tiktok_top_1000.csv', index_col=0)
df
# Out:
#          Rank            Account                Title  \
# Country
# All         1       billieeilish        BILLIE EILISH
# All         2           badbunny            Bad Bunny
# All         3  chipmunksoftiktok  Chipmunks of TikTok
# All         4      charlidamelio      charli d’amelio
# All         5         yessicadcs   Yessica y Moises 🦜
# ...       ...                ...                  ...
# All       996        leleburnier         LELÊ BURNIER
# All       997    sofiadelmonstro            Cat Sofia
# All       998               jena                 Jena
# All       999   christiandaloii_     Christiandaloii_
# All      1000        davidgetial               deivis
#
#                                               Link  Subscribers count  \
# Country
# All           https://www.tiktok.com/@billieeilish         41600000.0
# All               https://www.tiktok.com/@badbunny         13400000.0
# All      https://www.tiktok.com/@chipmunksoftiktok         11400000.0
# All          https://www.tiktok.com/@charlidamelio        135400000.0
# All             https://www.tiktok.com/@yessicadcs           263700.0
# ...                                            ...                ...
# All            https://www.tiktok.com/@leleburnier          1100000.0
# All        https://www.tiktok.com/@sofiadelmonstro          5200000.0
# All                   https://www.tiktok.com/@jena         10500000.0
# All       https://www.tiktok.com/@christiandaloii_          2700000.0
# All            https://www.tiktok.com/@davidgetial         13200000.0
#
#          Views avg.  Likes avg.  Comments avg.  Shares avg.  \
# Country
# All      95000000.0  18100000.0       151000.0      54800.0
# All      33300000.0   7300000.0       101900.0     106800.0
# All      25000000.0   3000000.0        21800.0      64200.0
# All      18700000.0   2600000.0        54700.0      35200.0
# All      16700000.0   1400000.0        16200.0     138400.0
# ...             ...         ...            ...          ...
# All       1200000.0    284300.0         2800.0        968.0
# All       2600000.0    161200.0         1300.0       1600.0
# All       2800000.0    320300.0          856.0        512.0
# All       1100000.0    188600.0         3000.0       2900.0
# All       2300000.0    337500.0         1400.0        212.0
#
#                             Scraped
# Country
# All      2022-02-07 16:54:35.641971
# All      2022-02-07 16:54:35.641971
# All      2022-02-07 16:54:35.641971
# All      2022-02-07 16:54:35.641971
# All      2022-02-07 16:54:35.641971
# ...                             ...
# All      2022-02-07 16:54:35.641971
# All      2022-02-07 16:54:35.641971
# All      2022-02-07 16:54:35.641971
# All      2022-02-07 16:54:35.641971
# All      2022-02-07 16:54:35.641971
#
# [1000 rows x 10 columns]

# %%
df = df.reset_index()

# %% [markdown]
# Explicar los datos y las variables disponibles en el conjunto de datos seleccionado:
# -  Esto se hace para que comprendais mejor los datos con los que estais trabajando.
# - Realizar un EDA sencillo para la variable dependiente y la variable independiente.

# %% [markdown]
#     Hacemos una limpieza inicial de las columnas que no vamos a utilizar.

# %%
df.head()
# Out:
#   Country  Rank            Account                Title  \
# 0     All     1       billieeilish        BILLIE EILISH
# 1     All     2           badbunny            Bad Bunny
# 2     All     3  chipmunksoftiktok  Chipmunks of TikTok
# 3     All     4      charlidamelio      charli d’amelio
# 4     All     5         yessicadcs   Yessica y Moises 🦜
#
#                                         Link  Subscribers count  Views avg.  \
# 0       https://www.tiktok.com/@billieeilish         41600000.0  95000000.0
# 1           https://www.tiktok.com/@badbunny         13400000.0  33300000.0
# 2  https://www.tiktok.com/@chipmunksoftiktok         11400000.0  25000000.0
# 3      https://www.tiktok.com/@charlidamelio        135400000.0  18700000.0
# 4         https://www.tiktok.com/@yessicadcs           263700.0  16700000.0
#
#    Likes avg.  Comments avg.  Shares avg.                     Scraped
# 0  18100000.0       151000.0      54800.0  2022-02-07 16:54:35.641971
# 1   7300000.0       101900.0     106800.0  2022-02-07 16:54:35.641971
# 2   3000000.0        21800.0      64200.0  2022-02-07 16:54:35.641971
# 3   2600000.0        54700.0      35200.0  2022-02-07 16:54:35.641971
# 4   1400000.0        16200.0     138400.0  2022-02-07 16:54:35.641971

# %%
df.drop(['Link', 'Country', 'Scraped', 'Title'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Rank', 'Account', 'Subscribers count', 'Views avg.', 'Likes avg.',
#        'Comments avg.', 'Shares avg.'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Rank                   int64
# Account               object
# Subscribers count    float64
# Views avg.           float64
# Likes avg.           float64
# Comments avg.        float64
# Shares avg.          float64
# dtype: object

# %% [markdown]
#     Vemos que hay mayusculas y minusculas en el nombre de las columnas y pasamos a ponerlas todas de un mismo tipo.

# %%
nuevas_columnas = {col:col.replace(" ","_").lower()for col in df.columns}
df.rename(columns = nuevas_columnas, inplace = True)

# %%
df.head(15)
# Out:
#     rank            account  subscribers_count  views_avg.  likes_avg.  \
# 0      1       billieeilish         41600000.0  95000000.0  18100000.0
# 1      2           badbunny         13400000.0  33300000.0   7300000.0
# 2      3  chipmunksoftiktok         11400000.0  25000000.0   3000000.0
# 3      4      charlidamelio        135400000.0  18700000.0   2600000.0
# 4      5         yessicadcs           263700.0  16700000.0   1400000.0
# 5      6            therock         49700000.0  24700000.0   3000000.0
# 6      7          the_pruld           433300.0  12200000.0   2700000.0
# 7      8         lukedonkin          2000000.0  14000000.0   2400000.0
# 8      9       mastertingus          1300000.0  13400000.0   2000000.0
# 9     10      txt.bighitent         15300000.0   7200000.0   2200000.0
# 10    11           besttoks          1800000.0  55900000.0   1500000.0
# 11    12    machinegunkelly          3200000.0  17500000.0   1400000.0
# 12    13   jenniferkershner            12500.0   6400000.0   1600000.0
# 13    14        noahschnapp         20100000.0   8600000.0   1800000.0
# 14    15       bdylanhollis          6400000.0   9100000.0   1500000.0
#
#     comments_avg.  shares_avg.
# 0        151000.0      54800.0
# 1        101900.0     106800.0
# 2         21800.0      64200.0
# 3         54700.0      35200.0
# 4         16200.0     138400.0
# 5         30900.0      16400.0
# 6         36300.0      56600.0
# 7         34000.0      54900.0
# 8         32500.0      44100.0
# 9         57200.0      31000.0
# 10         3300.0      12700.0
# 11        26800.0      23300.0
# 12        22600.0      62000.0
# 13        42000.0      11300.0
# 14        12400.0      46100.0

# %%
df['likes_avg.'].value_counts()
# Out:
# 1100000.0    13
# 1600000.0    10
# 1200000.0    10
# 1000000.0     7
# 1400000.0     5
#              ..
# 412900.0      1
# 330700.0      1
# 318800.0      1
# 376800.0      1
# 320300.0      1
# Name: likes_avg., Length: 874, dtype: int64

# %%
pd.set_option("display.float_format",lambda x: "%3.f" %x) #Usamos esta linea de código para que no aparezca los exponenciales
df.describe()
# Out:
#        rank  subscribers_count  views_avg.  likes_avg.  comments_avg.  \
# count  1000               1000        1000        1000           1000
# mean    500            7049170     3700866      453741           4559
# std     289           10872669     4697164      696476           7766
# min       1               4300      585300       31000              0
# 25%     251            1400000     1800000      230450           1600
# 50%     500            3700000     2600000      320200           2800
# 75%     750            8625000     4000000      478375           4900
# max    1000          135400000    95000000    18100000         151000
#
#        shares_avg.
# count         1000
# mean         10681
# std         167772
# min            212
# 25%           1200
# 50%           2400
# 75%           5400
# max        5300000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rank               1000 non-null   int64
#  1   account            1000 non-null   object
#  2   subscribers_count  1000 non-null   float64
#  3   views_avg.         1000 non-null   float64
#  4   likes_avg.         1000 non-null   float64
#  5   comments_avg.      1000 non-null   float64
#  6   shares_avg.        1000 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 54.8+ KB

# %%
df.stb.missing()
# Out:
#                    missing  total  percent
# rank                     0   1000        0
# account                  0   1000        0
# subscribers_count        0   1000        0
# views_avg.               0   1000        0
# likes_avg.               0   1000        0
# comments_avg.            0   1000        0
# shares_avg.              0   1000        0

# %% [markdown]
#     Como podemos observar en nuestra tabla de valores nulos, tenemos un DF bastante limpio.

# %%
df.shape
# Out:
# (1000, 7)

# %% [markdown]
#     Confirmamos que tenemos 1000 filas por los 1000 artistas más famoso de Tiktok.

# %% [markdown]
#      Al ver que no tenemos nulos y que nuestras variables tienen diferentes valores, vemos poco informativo comprobar los valores únicos(unique) y su frecuencia(value_counts).

# %% [markdown]
# Realiza el ajuste lineal simple utilizando diversas métricas y realiza una gráfica mostrando los resultados e interpretalos.
